# %%
import sys
import pandas as pd
import matplotlib
import seaborn
import sklearn
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import preprocessing

# %%
train=pd.read_csv('train.csv')
test=pd.read_csv('test.csv')

# %%
train.head()
# Out:
#    ID_1  -64  -56  -61  -66  -71  -82  -81  1
# 0  ID_2  -68  -57  -61  -65  -71  -85  -85  1
# 1  ID_3  -63  -60  -60  -67  -76  -85  -84  1
# 2  ID_4  -61  -60  -68  -62  -77  -90  -80  1
# 3  ID_5  -63  -65  -60  -63  -77  -81  -87  1
# 4  ID_6  -64  -55  -63  -66  -76  -88  -83  1

# %%
train.shape
# Out:
# (1499, 9)

# %%
train = pd.read_csv("train.csv", sep=',', 
                  names = ["ID", "a1", "a2", "a3", "a4", "a5", "a6", "a7", "r"])

# %%
train.head()
# Out:
#      ID  a1  a2  a3  a4  a5  a6  a7  r
# 0  ID_1 -64 -56 -61 -66 -71 -82 -81  1
# 1  ID_2 -68 -57 -61 -65 -71 -85 -85  1
# 2  ID_3 -63 -60 -60 -67 -76 -85 -84  1
# 3  ID_4 -61 -60 -68 -62 -77 -90 -80  1
# 4  ID_5 -63 -65 -60 -63 -77 -81 -87  1

# %%
from sklearn.utils import shuffle
train = shuffle(train)

# %%
train.head()
# Out:
#            ID  a1  a2  a3  a4  a5  a6  a7  r
# 908    ID_909 -51 -52 -51 -51 -64 -79 -89  3
# 673    ID_674 -41 -58 -60 -47 -70 -82 -74  2
# 969    ID_970 -51 -56 -60 -48 -60 -86 -83  3
# 1340  ID_1341 -64 -57 -48 -60 -39 -88 -85  4
# 509    ID_510 -40 -56 -56 -38 -66 -77 -74  2

# %%
train.describe()
# Out:
#                 a1          a2           a3           a4           a5  \
# count  1500.000000  1500.00000  1500.000000  1500.000000  1500.000000
# mean    -52.319333   -55.95800   -55.319333   -53.800667   -62.905333
# std      11.672883     3.37834     5.132666    11.732435     9.127024
# min     -74.000000   -74.00000   -73.000000   -77.000000   -89.000000
# 25%     -61.000000   -58.00000   -58.250000   -63.000000   -69.000000
# 50%     -55.000000   -56.00000   -55.000000   -56.000000   -64.000000
# 75%     -46.000000   -54.00000   -52.000000   -47.000000   -56.000000
# max     -10.000000   -46.00000   -40.000000   -11.000000   -36.000000
#
#                 a6           a7            r
# count  1500.000000  1500.000000  1500.000000
# mean    -81.188000   -81.973333     2.500000
# std       6.679002     6.676002     1.118407
# min     -97.000000   -98.000000     1.000000
# 25%     -86.000000   -87.000000     1.750000
# 50%     -82.000000   -83.000000     2.500000
# ...

# %%
from sklearn.model_selection import train_test_split
#training set
train_set=train.sample(frac=0.7,random_state=1)
#test set
test_set=train.loc[~train.index.isin(train_set.index)]
print(train_set.shape)
print(test_set.shape)
# Out:
# (1050, 9)
# (450, 9)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Fixing random state for reproducibility
np.random.seed(19680801)



x = train['r']
y = train['a1']

area = (30 * np.random.rand(10))**2  # 0 to 15 point radii

plt.scatter(x, y, alpha=.5)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Fixing random state for reproducibility
np.random.seed(19680801)



x = train['r']
y = train['a3']

area = (30 * np.random.rand(10))**2  # 0 to 15 point radii

plt.scatter(x, y, alpha=.5)
plt.show()

# %%
from sklearn.cluster import KMeans
import numpy as np

kmeans = KMeans().fit(train_set[col])
kmeans.labels_

kmeans.predict(test_set[col])

kmeans.cluster_centers_
# Out:
# array([[-60.60606061, -54.91515152, -58.4969697 , -62.80606061,
#         -67.94545455, -81.43636364, -82.43030303],
#        [-43.78666667, -57.4       , -57.49333333, -44.28      ,
#         -69.77333333, -78.17333333, -77.33333333],
#        [-62.83870968, -57.37096774, -51.71774194, -64.58064516,
#         -48.18548387, -89.12903226, -88.66935484],
#        [-38.25694444, -55.8125    , -55.34722222, -39.70833333,
#         -66.20833333, -69.99305556, -71.        ],
#        [-49.56870229, -55.09923664, -52.75954198, -50.72900763,
#         -63.45419847, -81.35496183, -82.56870229],
#        [-64.60526316, -58.47368421, -63.00877193, -66.48245614,
#         -74.13157895, -86.14912281, -87.01754386],
#        [-17.        , -58.725     , -59.275     , -21.8       ,
#         -70.525     , -72.9       , -74.35      ],
#        [-58.66666667, -53.83333333, -51.33333333, -59.35714286,
#         -51.25396825, -85.65873016, -86.07936508]])

# %%
col=["a1", "a2", "a3", "a4", "a5", "a6", "a7"]

# %%
target="r"

# %%
train
# Out:
#            ID  a1  a2  a3  a4  a5  a6  a7  r
# 556    ID_557 -42 -57 -51 -41 -69 -77 -75  2
# 143    ID_144 -63 -57 -65 -71 -75 -82 -86  1
# 1434  ID_1435 -57 -56 -49 -58 -50 -87 -85  4
# 1262  ID_1263 -66 -57 -55 -65 -48 -91 -87  4
# 1345  ID_1346 -61 -57 -51 -56 -49 -88 -85  4
# 1342  ID_1343 -63 -62 -49 -63 -45 -92 -86  4
# 896    ID_897 -50 -55 -54 -50 -69 -79 -82  3
# 272    ID_273 -58 -51 -59 -63 -69 -81 -80  1
# 812    ID_813 -46 -53 -52 -45 -62 -79 -78  3
# 843    ID_844 -47 -58 -56 -44 -64 -80 -85  3
# 684    ID_685 -45 -57 -55 -48 -67 -77 -84  2
# 658    ID_659 -35 -58 -50 -35 -62 -72 -67  2
# 291    ID_292 -60 -57 -58 -66 -65 -77 -80  1
# 166    ID_167 -62 -58 -59 -66 -68 -87 -88  1
# 1240  ID_1241 -63 -59 -51 -72 -55 -96 -92  4
# 861    ID_862 -51 -55 -50 -50 -59 -79 -85  3
# 388    ID_389 -40 -56 -58 -42 -67 -62 -71  2
# 960    ID_961 -49 -59 -57 -50 -72 -80 -91  3
# 27      ID_28 -66 -57 -65 -69 -78 -85 -85  1
# 249    ID_250 -56 -56 -62 -64 -70 -79 -86  1
# ...

# %%
from sklearn.naive_bayes import GaussianNB
clf = GaussianNB()
clf.fit(train_set[col],train_set[target])
predictions = clf.predict(test_set[col])

# %%
new_list = []
for item in predictions:
    new_list.append(int(round(item)))

# %%
print(new_list)
# Out:
# [2, 2, 1, 2, 1, 3, 1, 2, 3, 3, 3, 1, 4, 1, 3, 4, 4, 2, 2, 4, 4, 2, 4, 1, 4, 4, 1, 2, 3, 1, 4, 3, 2, 2, 4, 4, 3, 2, 1, 4, 3, 3, 1, 2, 2, 2, 1, 4, 1, 3, 2, 3, 1, 4, 3, 3, 3, 1, 1, 1, 3, 3, 3, 3, 3, 2, 3, 1, 4, 1, 4, 3, 1, 3, 2, 1, 3, 2, 4, 4, 1, 1, 1, 2, 2, 3, 4, 1, 1, 1, 1, 1, 1, 4, 4, 3, 3, 4, 3, 4, 1, 1, 2, 1, 3, 4, 3, 3, 3, 1, 1, 3, 3, 3, 2, 3, 1, 2, 1, 3, 2, 4, 3, 1, 2, 4, 4, 1, 3, 1, 2, 3, 2, 4, 1, 2, 4, 3, 1, 1, 2, 1, 3, 4, 4, 4, 4, 3, 4, 4, 1, 4, 1, 1, 1, 3, 3, 1, 1, 3, 3, 1, 1, 2, 1, 2, 1, 4, 1, 3, 3, 2, 1, 4, 3, 4, 2, 4, 1, 4, 3, 3, 4, 2, 3, 3, 1, 4, 4, 2, 2, 4, 2, 2, 4, 4, 1, 3, 3, 2, 2, 1, 4, 1, 1, 3, 1, 4, 2, 3, 3, 3, 3, 4, 2, 1, 4, 4, 2, 4, 4, 3, 4, 3, 4, 4, 3, 3, 1, 2, 4, 1, 2, 3, 4, 3, 4, 2, 2, 1, 1, 2, 3, 2, 1, 3, 2, 3, 2, 4, 4, 1, 1, 1, 1, 4, 2, 1, 4, 2, 3, 1, 2, 3, 4, 2, 4, 2, 4, 1, 1, 2, 2, 4, 1, 3, 3, 4, 3, 3, 4, 4, 2, 3, 1, 4, 1, 1, 2, 4, 1, 4, 4, 2, 2, 3, 2, 1, 4, 2, 4, 1, 2, 3, 1, 3, 2, 3, 3, 2, 2, 4, 3, 3, 1, 1, 2, 4, 3, 2, 2, 2, 1, 2, 3, 3, 3, 4, 2, 1, 2, 2, 3
# ...

# %%
import numpy as np
from sklearn.metrics import accuracy_score

accuracy_score(test_set[target], new_list)

accuracy_score(test_set[target], new_list, normalize=False)
# Out:
# 440

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(new_list,test_set[target])
# Out:
# 0.04666666666666667

# %%
test = pd.read_csv("test.csv", sep=',', 
                  names = ["ID", "a1", "a2", "a3", "a4", "a5", "a6", "a7"])

# %%
test.head()
# Out:
#      ID  a1  a2  a3  a4  a5  a6  a7
# 0  ID_1 -62 -51 -54 -60 -74 -74 -82
# 1  ID_2 -57 -54 -51 -60 -47 -84 -88
# 2  ID_3 -56 -55 -44 -60 -51 -84 -86
# 3  ID_4 -19 -60 -54 -35 -69 -69 -78
# 4  ID_5 -67 -56 -60 -66 -73 -93 -87

# %%
clf.fit(train[col],train[target])
predictions = clf.predict(test[col])

# %%
new_lis = []
for item in predictions:
    new_lis.append(int(round(item)))

# %%
print(new_lis)
# Out:
# [1, 4, 4, 2, 1, 3, 1, 4, 2, 2, 3, 4, 4, 2, 1, 3, 3, 3, 1, 3, 2, 3, 3, 4, 2, 2, 4, 4, 2, 4, 3, 4, 2, 1, 3, 3, 2, 1, 1, 4, 3, 1, 1, 1, 4, 4, 3, 3, 4, 3, 4, 1, 4, 1, 1, 1, 1, 2, 2, 1, 2, 4, 4, 3, 1, 4, 4, 1, 2, 4, 1, 2, 2, 3, 4, 1, 3, 4, 3, 3, 3, 2, 2, 4, 2, 4, 4, 4, 2, 4, 4, 2, 4, 4, 3, 3, 4, 1, 3, 1, 1, 1, 1, 3, 2, 2, 3, 4, 1, 3, 1, 2, 4, 2, 4, 1, 4, 2, 3, 2, 4, 4, 2, 3, 2, 3, 3, 3, 2, 2, 3, 3, 4, 4, 3, 1, 4, 4, 2, 4, 1, 4, 4, 4, 1, 1, 2, 1, 3, 3, 4, 3, 3, 3, 2, 4, 4, 4, 2, 1, 2, 2, 2, 1, 2, 4, 1, 3, 4, 2, 2, 1, 2, 1, 3, 1, 2, 3, 2, 3, 4, 3, 3, 1, 3, 1, 1, 4, 2, 3, 3, 1, 4, 4, 2, 2, 2, 4, 3, 4, 4, 3, 2, 3, 3, 1, 1, 2, 1, 4, 4, 3, 2, 3, 2, 1, 1, 2, 1, 3, 3, 1, 4, 1, 2, 3, 1, 3, 2, 4, 3, 3, 1, 4, 3, 3, 2, 4, 2, 1, 2, 2, 4, 1, 1, 4, 2, 3, 3, 1, 1, 3, 3, 1, 2, 4, 4, 4, 4, 4, 3, 2, 3, 1, 3, 3, 1, 2, 2, 1, 4, 1, 1, 2, 3, 4, 1, 1, 1, 2, 4, 4, 1, 3, 1, 3, 3, 1, 1, 3, 3, 3, 2, 1, 3, 4, 3, 2, 3, 3, 1, 2, 2, 1, 1, 1, 1, 1, 1, 4, 4, 4, 3, 2, 1, 3, 4, 3, 1, 1, 4, 4, 4, 2, 2, 2, 1, 3, 4, 4, 1, 4, 1
# ...

# %%
my_submission = pd.DataFrame({'Id': test.ID, 'Room': new_lis})

my_submission.to_csv('submission.csv', index=False)
